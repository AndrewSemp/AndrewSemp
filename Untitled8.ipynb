# %% [markdown]
# <a href="https://colab.research.google.com/github/AndrewSemp/AndrewSemp/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(1)
dados = np.random.normal(loc=20, scale=2, size=1000)
plt.hist(dados, color = "lightblue", ec="red")
# Out:
# (array([ 10.,  37., 103., 223., 286., 224.,  90.,  24.,   1.,   2.]),
#  array([13.89247124, 15.29494466, 16.69741807, 18.09989149, 19.50236491,
#         20.90483832, 22.30731174, 23.70978516, 25.11225857, 26.51473199,
#         27.91720541]),
#  <BarContainer object of 10 artists>)
